# %% [markdown]
# # Exploratory Data Analysis of Wine Dataset

# %% [markdown]
# ## Load and Inspect the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = '../../preprocessed_winemag-data copy.csv'  
df = pd.read_csv(file_path)

df.head()
# Out:
#    id   country                                        description  \
# 0   1  Portugal  This is ripe and fruity, a wine that is smooth...
# 1   3        US  Pineapple rind, lemon pith and orange blossom ...
# 2   4        US  Much like the regular bottling from 2012, this...
# 3   5     Spain  Blackberry and raspberry aromas show a typical...
# 4   6     Italy  Here's a bright, informal red that opens with ...
#
#                           designation  points  price           province  \
# 0                            Avidagos      87   15.0              Douro
# 1                Reserve Late Harvest      87   13.0           Michigan
# 2  Vintner's Reserve Wild Child Block      87   65.0             Oregon
# 3                        Ars In Vitro      87   15.0     Northern Spain
# 4                             Belsito      87   16.0  Sicily & Sardinia
#
#                                                title             variety  \
# 0      Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 1  St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 2  Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# 3  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...  Tempranillo-Merlot
# 4   Terre di Giurfo 2013 Belsito Frappato (Vittoria)            Frappato
#
#                 winery
# 0  Quinta dos Avidagos
# 1           St. Julian
# 2         Sweet Cheeks
# 3               Tandem
# 4      Terre di Giurfo

# %% [markdown]
# ## Data Description

# %%
df.describe()
# Out:
#                   id        points         price
# count   86148.000000  86148.000000  86148.000000
# mean    65008.434729     88.729907     37.556403
# std     37531.085008      3.051980     36.390439
# min         1.000000     80.000000      4.000000
# 25%     32448.500000     87.000000     18.000000
# 50%     65192.500000     89.000000     28.000000
# 75%     97470.500000     91.000000     45.000000
# max    129970.000000    100.000000   2013.000000

# %%
df.nunique()
# Out:
# id             86148
# country           41
# description    79477
# designation    35750
# points            21
# price            330
# province         402
# title          78719
# variety          630
# winery         11762
# dtype: int64

# %%
import pycountry_convert as pc

def country_to_continent(country_name):
    try:
        country_alpha2 = pc.country_name_to_country_alpha2(country_name)
        country_continent_code = pc.country_alpha2_to_continent_code(country_alpha2)
        country_continent_name = pc.convert_continent_code_to_continent_name(country_continent_code)
    except:
        if country_name == 'US':
            return 'North America'
        elif country_name == 'England':
            return 'Europe'
        return 'Not found'  # Returns 'Not found' if the country name is not recognized. I checked and it recognizes all
    return country_continent_name

df['continent'] = df['country'].apply(country_to_continent)
# Out:
# /Users/carloscc/anaconda3/envs/deepl/lib/python3.11/site-packages/pycountry/db.py:51: UserWarning: Country's official_name not found. Country name provided instead.
#   warnings.warn(warning_message, UserWarning)
# /Users/carloscc/anaconda3/envs/deepl/lib/python3.11/site-packages/pycountry/db.py:51: UserWarning: Country's common_name not found. Country name provided instead.
#   warnings.warn(warning_message, UserWarning)

# %%
df_treemap = pd.DataFrame(df.copy().groupby(['continent', 'country', 'province', 'winery']).size(), columns=['count'])

def df_to_nested_dict(df):
    result = {}
    for index, value in df.iterrows():
        # Navigate through the multi-index and assign the value
        d = result
        for level in index[:-1]:  # Go until the second last index level
            if level not in d:
                d[level] = {}
            d = d[level]
        # Assign the count to the last level
        d[index[-1]] = int(value['count'])
    return result

# Convert and print the nested dictionary
nested_dict = df_to_nested_dict(df_treemap)

# %%
df_treemap
# Out:
#            continent       country    province            winery  count
# 0             Africa       Morocco  Guerrouane    Bernard Magrez      3
# 1             Africa       Morocco     Morocco      Ouled Thaleb      5
# 2             Africa       Morocco      Zenata      Ouled Thaleb      8
# 3             Africa  South Africa   Bot River          Beaumont      1
# 4             Africa  South Africa   Bot River        Wildekrans      1
# ...              ...           ...         ...               ...    ...
# 13404  South America       Uruguay     Uruguay  Familia Traversa      2
# 13405  South America       Uruguay     Uruguay            Garzón      7
# 13406  South America       Uruguay     Uruguay    Gimenez Mendez      1
# 13407  South America       Uruguay     Uruguay           Narbona      3
# 13408  South America       Uruguay     Uruguay          Pizzorno      1
#
# [13409 rows x 5 columns]

# %%
def build_hierarchy(df):
    result = {'name': 'Continents', 'children': []}
    for continent, continent_df in df.groupby('continent'):
        continent_dict = {'name': continent, 'children': []}
        for country, country_df in continent_df.groupby('country'):
            country_dict = {'name': country, 'children': []}
            for province, province_df in country_df.groupby('province'):
                total_province_count = province_df['count'].sum()
                province_dict = {'name': province, 'children': []}
                other_winery_count = 0

                for idx, row in province_df.iterrows():
                    if (row['count'] / total_province_count) >= 0.002:
                        winery_dict = {'name': row['winery'], 'value': row['count']}
                        province_dict['children'].append(winery_dict)
                    else:
                        other_winery_count += row['count']

                if other_winery_count > 0:
                    province_dict['children'].append({'name': 'Other wineries', 'value': other_winery_count})
                
                country_dict['children'].append(province_dict)
            continent_dict['children'].append(country_dict)
        result['children'].append(continent_dict)
    return result

# Generate the JSON structure
hierarchy_json = build_hierarchy(df_treemap)

# %%
hierarchy_json
# Out:
# {'name': 'Continents',
#  'children': [{'name': 'Africa',
#    'children': [{'name': 'Morocco',
#      'children': [{'name': 'Guerrouane',
#        'children': [{'name': 'Bernard Magrez', 'value': 3}]},
#       {'name': 'Morocco', 'children': [{'name': 'Ouled Thaleb', 'value': 5}]},
#       {'name': 'Zenata', 'children': [{'name': 'Ouled Thaleb', 'value': 8}]}]},
#     {'name': 'South Africa',
#      'children': [{'name': 'Bot River',
#        'children': [{'name': 'Beaumont', 'value': 1},
#         {'name': 'Wildekrans', 'value': 1}]},
#       {'name': 'Breedekloof',
#        'children': [{'name': 'Lions Drift', 'value': 2}]},
#       {'name': 'Cape Agulhas', 'children': [{'name': 'Lomond', 'value': 1}]},
#       {'name': 'Cape Peninsula',
#        'children': [{'name': 'Cape Point Vineyards', 'value': 1}]},
#       {'name': 'Cederberg', 'children': [{'name': 'Cederberg', 'value': 1}]},
#       {'name': 'Coastal Region',
#        'children': [{'name': 'A.A. Badenhorst Family Wines', 'value': 1},
#         {'name': 'Avondale', 'value': 1},
#         {'name': 'Backsberg', 'value': 2},
#         {'name': 'Bellingham', 'value': 11},
#         {'name': 'Beyerskloof', 'value': 1},
#         {'name': 'Boschendal', 'value': 4},
#         {'name': 'Brampton', 'value': 1},
#         {'name': 'Buitenverwachting', 'value': 2},
#         {'name': 'De Toren', 'value': 1},
#         {'name': 'Delaire Graff', 'value': 2},
#         {'name': "Dixon's Peak", 'value': 1},
#         {'name': 'Fable Mountain', 'value': 2},
#         {'name': 'Fleur Du Cap', 'value': 4},
#         {'name': 'Goats do Roam Wine Co.', 'value': 2},
#         {'name': 'Graham Beck', 'value': 5},
#         {'name': 'Groote Post', 'value': 1},
#         {'name': 'Juno', 'value': 1},
#         {'name': 'KWV', 'value': 2},
#         {'name': 'MAN Family Wines', 'value': 4},
#         {'name': 'MAN Vintners', 'value': 2},
#         {'name': 'Miles Mossop', 'value': 2},
#         {'name': 'Mulderbosch', 'value': 2},
#         {'name': 'Noble Hill', 'value': 1},
#         {'name': 'Painted Wolf', 'value': 3},
#         {'name': 'Protea', 'value': 1},
#         {'name': 'Raats Family', 'value': 6},
#         {'name': 'Saronsberg', 'value': 1},
#         {'name': 'Solms-Delta', 'value': 1},
#         {'name': 'Spier', 'value': 5},
#         {'name': 'Steenberg', 'value': 1},
#         {'name': 'The Foundry', 'value': 1},
#         {'name': 'The Yellow Cellar', 'value': 1},
#         {'name': 'Warwick', 'value': 1}]},
#       {'name': 'Constantia',
#        'children': [{'name': 'Buitenverwachting', 'value': 5},
#         {'name': 'Constantia Glen', 'value': 2},
#         {'name': 'Klein Constantia', 'value': 3}]},
#       {'name': 'Darling', 'children': [{'name': 'Ormonde', 'value': 1}]},
#       {'name': 'Durbanville',
#        'children': [{'name': "D'Aria", 'value': 1},
#         {'name': 'Durbanville Hills', 'value': 1},
#         {'name': 'Emineo', 'value': 1}]},
#       {'name': 'Eilandia', 'children': [{'name': 'Bon Cap', 'value': 3}]},
#       {'name': 'Elgin',
#        'children': [{'name': 'Boschendal', 'value': 1},
#         {'name': 'Elgin Vintners', 'value': 1},
#         {'name': 'KWV', 'value': 1},
#         {'name': 'Kershaw', 'value': 4},
#         {'name': 'Oak Valley', 'value': 1},
#         {'name': 'Paul Cluver', 'value': 6},
#         {'name': 'Radford Dale', 'value': 1},
#         {'name': 'Rudera', 'value': 1},
#         {'name': 'South Hill', 'value': 1},
#         {'name': 'Thelema', 'value': 5}]},
#       {'name': 'Elim', 'children': [{'name': 'Trizanne', 'value': 1}]},
#       {'name': 'Franschhoek',
#        'children': [{'name': 'Anthonij Rupert', 'value': 1},
#         {'name': 'Bellingham', 'value': 2},
#         {'name': 'Black Elephant', 'value': 1},
#         {'name': 'Boekenhoutskloof', 'value': 1},
#         {'name': 'Chamonix', 'value': 4},
#         {'name': 'Haute Cabrière', 'value': 2},
#         {'name': 'La Motte', 'value': 1}]},
#       {'name': 'Groenekloof',
#        'children': [{'name': 'Neil Ellis', 'value': 1}]},
#       {'name': 'Helderberg',
#        'children': [{'name': 'de Trafford', 'value': 1}]},
#       {'name': 'Hemel en Aarde',
#        'children': [{'name': 'Bouchard Finlayson', 'value': 1}]},
#       {'name': 'Jonkershoek Valley',
#        'children': [{'name': 'Neil Ellis', 'value': 1},
#         {'name': 'Stark-Condé', 'value': 3}]},
#       {'name': 'Malgas', 'children': [{'name': 'Sijnn', 'value': 1}]},
#       {'name': 'Northern Cape',
#        'children': [{'name': 'Orange River Wine Cellars', 'value': 2}]},
#       {'name': 'Olifants River', 'children': [{'name': 'Alheit', 'value': 1}]},
#       {'name': 'Overberg',
#        'children': [{'name': 'Bouchard Finlayson', 'value': 4},
#         {'name': 'Slowine', 'value': 1}]},
#       {'name': 'Paarl',
#        'children': [{'name': 'Avondale', 'value': 5},
#         {'name': 'Backsberg', 'value': 3},
#         {'name': 'Bellingham', 'value': 1},
#         {'name': 'Black Pearl', 'value': 2},
#         {'name': 'Fairview', 'value': 8},
#         {'name': 'Glen Carlou', 'value': 7},
#         {'name': 'Graham Beck', 'value': 1},
#         {'name': 'KWV', 'value': 1},
#         {'name': 'Landskroon', 'value': 2},
#         {'name': 'Niel Joubert', 'value': 3},
#         {'name': 'Tormentoso', 'value': 2},
#         {'name': 'Vilafonté', 'value': 13},
#         {'name': 'Wamakersvallei', 'value': 2}]},
#       {'name': 'Philadelphia', 'children': [{'name': 'Capaia', 'value': 3}]},
#       {'name': 'Polkadraai Hills',
#        'children': [{'name': 'Stellenbosch Hills', 'value': 3}]},
#       {'name': 'Robertson',
#        'children': [{'name': 'Bon Cap', 'value': 2},
#         {'name': 'Danie de Wet', 'value': 4},
#         {'name': 'De Wetshof', 'value': 11},
#         {'name': 'Enon', 'value': 1},
#         {'name': 'Excelsior', 'value': 1},
#         {'name': 'Graham Beck', 'value': 9},
#         {'name': 'Rietvallei Estate Wine', 'value': 3},
#         {'name': 'Robertson Winery', 'value': 10},
#         {'name': 'Rooiberg', 'value': 2},
#         {'name': 'Springfield Estate', 'value': 4},
#         {'name': 'Van Loveren', 'value': 5},
#         {'name': 'Weltevrede', 'value': 1}]},
#       {'name': 'Simonsberg-Paarl',
#        'children': [{'name': 'Noble Hill', 'value': 1},
#         {'name': 'Vrede en Lust', 'value': 2}]},
#       {'name': 'Simonsberg-Stellenbosch',
#        'children': [{'name': 'Delheim', 'value': 2},
#         {'name': 'Glenelly', 'value': 1},
#         {'name': 'Kanonkop', 'value': 8},
#         {'name': 'Morgenhof', 'value': 5},
#         {'name': 'Muratie', 'value': 3},
#         {'name': 'Remhoogte', 'value': 2},
#         {'name': 'Rustenberg', 'value': 2},
#         {'name': 'Warwick', 'value': 2}]},
#       {'name': 'South Africa',
#        'children': [{'name': 'Fat Barrel', 'value': 1},
#         {'name': 'Fleur Du Cap', 'value': 1},
#         {'name': 'Longridge', 'value': 1}]},
#       {'name': 'Stellenbosch',
#        'children': [{'name': 'Beau Joubert', 'value': 10},
#         {'name': 'Beyerskloof', 'value': 3},
#         {'name': 'Bradgate', 'value': 4},
#         {'name': 'Camberley', 'value': 3},
#         {'name': 'Cape View', 'value': 1},
#         {'name': 'De Toren', 'value': 13},
#         {'name': 'DeMorgenzon', 'value': 7},
#         {'name': 'DeWaal', 'value': 2},
#         {'name': 'Dornier', 'value': 2},
#         {'name': 'Edgebaston', 'value': 4},
#         {'name': 'Eikendal', 'value': 2},
#         {'name': 'Ernie Els', 'value': 11},
#         {'name': 'Ernst Gouws & Co.', 'value': 1},
#         {'name': 'Fleur Du Cap', 'value': 4},
#         {'name': 'Glenelly', 'value': 5},
#         {'name': 'Graham Beck', 'value': 2},
#         {'name': 'Hartenberg', 'value': 10},
#         {'name': 'Jardin', 'value': 14},
#         {'name': 'Kanonkop', 'value': 5},
#         {'name': 'Ken Forrester', 'value': 5},
#         {'name': 'Kleinood', 'value': 1},
#         {'name': "L'Avenir", 'value': 2},
#         {'name': 'Land of Hope', 'value': 1},
#         {'name': 'Le Riche', 'value': 2},
#         {'name': 'Leopard Frog', 'value': 1},
#         {'name': 'Longridge', 'value': 1},
#         {'name': 'Lourensford', 'value': 1},
#         {'name': 'Malan', 'value': 1},
#         {'name': 'Mas Nicolas', 'value': 1},
#         {'name': 'Meerlust', 'value': 2},
#         {'name': 'Morgenhof', 'value': 8},
#         {'name': 'Mulderbosch', 'value': 6},
#         {'name': 'Muratie', 'value': 2},
#         {'name': 'Mvemve Raats', 'value': 5},
#         {'name': 'Neethlingshof', 'value': 2},
#         {'name': 'Peter Andrew', 'value': 1},
#         {'name': 'Post House', 'value': 2},
#         {'name': 'Raats Family', 'value': 4},
#         {'name': 'Radford Dale', 'value': 2},
#         {'name': 'Remhoogte', 'value': 2},
#         {'name': 'Reyneke', 'value': 3},
#         {'name': 'Rudera', 'value': 3},
#         {'name': 'Rust en Vrede', 'value': 4},
#         {'name': 'Rustenberg', 'value': 5},
#         {'name': 'Saxenburg Estate', 'value': 3},
#         {'name': 'Simonsig', 'value': 17},
#         {'name': 'Spier', 'value': 4},
#         {'name': 'Stark-Condé', 'value': 8},
#         {'name': 'Stellenbosch Vineyards', 'value': 1},
#         {'name': 'Thelema', 'value': 2},
#         {'name': 'Tokara', 'value': 2},
#         {'name': 'Tumara', 'value': 2},
#         {'name': 'Vergelegen', 'value': 5},
#         {'name': 'Warwick', 'value': 7},
#         {'name': 'Waterford', 'value': 3},
#         {'name': 'Waterkloof', 'value': 2},
#         {'name': 'Winery of Good Hope', 'value': 5},
#         {'name': 'Xavier Flouret', 'value': 2},
#         {'name': 'de Trafford', 'value': 1}]},
#       {'name': 'Swartland',
#        'children': [{'name': 'A.A. Badenhorst Family Wines', 'value': 2},
#         {'name': 'Allesverloren', 'value': 1},
#         {'name': 'Black Rock', 'value': 2},
#         {'name': 'Lammershoek', 'value': 3},
#         {'name': 'Mullineux', 'value': 6},
#         {'name': 'Org de Rac', 'value': 1},
#         {'name': 'Painted Wolf', 'value': 3},
#         {'name': 'Riebeek Cellars', 'value': 7},
#         {'name': 'Sadie Family', 'value': 4},
#         {'name': 'Sequillo', 'value': 2},
#         {'name': 'Spice Route', 'value': 3},
#         {'name': 'Terre Brûlée', 'value': 2},
#         {'name': 'The Royal Valley Vineyards Wine Company', 'value': 1}]},
#       {'name': 'Tulbagh',
#        'children': [{'name': "Rijk's", 'value': 4},
#         {'name': 'Saronsberg', 'value': 3}]},
#       {'name': 'Walker Bay',
#        'children': [{'name': 'B Vintners', 'value': 1},
#         {'name': 'Beaumont', 'value': 1},
#         {'name': 'Bouchard Finlayson', 'value': 2},
#         {'name': 'Hermanuspietersfontein', 'value': 1},
#         {'name': 'La Vierge', 'value': 1}]},
#       {'name': 'Wellington',
#        'children': [{'name': 'Appollis', 'value': 1},
#         {'name': 'Diemersfontein', 'value': 3},
#         {'name': 'Doolhof', 'value': 2},
#         {'name': 'Nabygelegen', 'value': 2},
#         {'name': 'Thokozani', 'value': 1},
#         {'name': 'Wamakersvallei', 'value': 1}]},
#       {'name': 'Western Cape',
#        'children': [{'name': 'Alheit', 'value': 1},
#         {'name': 'Allée Bleue', 'value': 1},
#         {'name': 'Ataraxia', 'value': 1},
#         {'name': 'Bizoe', 'value': 3},
#         {'name': 'Boekenhoutskloof', 'value': 6},
#         {'name': 'Boschendal', 'value': 2},
#         {'name': 'Botanica', 'value': 1},
#         {'name': 'Bouchard Finlayson', 'value': 2},
#         {'name': 'Buitenverwachting', 'value': 1},
#         {'name': 'DeMorgenzon', 'value': 4},
#         {'name': 'Dornier', 'value': 1},
#         {'name': 'Douglas Green', 'value': 4},
#         {'name': 'Eikeboom', 'value': 1},
#         {'name': 'Eikendal', 'value': 1},
#         {'name': 'Ernie Els', 'value': 2},
#         {'name': 'Fable Mountain', 'value': 1},
#         {'name': 'Fat Barrel', 'value': 1},
#         {'name': 'Flagstone', 'value': 1},
#         {'name': 'Fleur Du Cap', 'value': 6},
#         {'name': 'Franschhoek Cellar', 'value': 1},
#         {'name': 'Frisky Zebras', 'value': 1},
#         {'name': 'Glenelly', 'value': 2},
#         {'name': 'Goats do Roam Wine Co.', 'value': 2},
#         {'name': 'Graceland', 'value': 1},
#         {'name': 'Graham Beck', 'value': 9},
#         {'name': 'Guardian Peak', 'value': 1},
#         {'name': 'Havana Hills', 'value': 1},
#         {'name': 'Herding Cats', 'value': 1},
#         {'name': 'Indaba', 'value': 1},
#         {'name': 'Jean Daneel', 'value': 2},
#         {'name': 'Juno', 'value': 3},
#         {'name': 'KWV', 'value': 8},
#         {'name': 'Ken Forrester', 'value': 6},
#         {'name': 'Laroche', 'value': 1},
#         {'name': "Leopard's Leap", 'value': 1},
#         {'name': 'Lime Road', 'value': 1},
#         {'name': 'Makulu', 'value': 1},
#         {'name': 'Mulderbosch', 'value': 2},
#         {'name': 'Mwitu', 'value': 1},
#         {'name': 'Nederburg', 'value': 10},
#         {'name': 'Neil Ellis', 'value': 10},
#         {'name': 'Quiet Resolve', 'value': 1},
#         {'name': 'Releaf', 'value': 3},
#         {'name': 'Shark Trust', 'value': 1},
#         {'name': 'Simonsig', 'value': 1},
#         {'name': 'Solms-Delta', 'value': 3},
#         {'name': 'Spier', 'value': 3},
#         {'name': 'Steenberg', 'value': 1},
#         {'name': 'The Big Five Collection', 'value': 1},
#         {'name': 'Val du Charron', 'value': 1},
#         {'name': 'Van Loveren', 'value': 1},
#         {'name': "Vins d'Orrance", 'value': 4},
#         {'name': 'Vintales', 'value': 3},
#         {'name': 'Warwick', 'value': 1},
#         {'name': 'Winery of Good Hope', 'value': 3}]}]}]},
#   {'name': 'Asia',
#    'children': [{'name': 'Armenia',
#      'children': [{'name': 'Armenia',
#        'children': [{'name': 'Van Ardi', 'value': 2}]}]},
#     {'name': 'China',
#      'children': [{'name': 'China',
#        'children': [{'name': 'Chateau Changyu-Castel', 'value': 1}]}]},
#     {'name': 'Cyprus',
#      'children': [{'name': 'Commandaria',
#        'children': [{'name': 'Etko', 'value': 1},
#         {'name': 'Loel', 'value': 1}]},
#       {'name': 'Cyprus',
#        'children': [{'name': 'Chrysorroyiatissa', 'value': 2},
#         {'name': 'Panayia', 'value': 1}]},
#       {'name': 'Kathikas', 'children': [{'name': 'Kathikac', 'value': 1}]},
#       {'name': 'Pafos',
#        'children': [{'name': 'Chrysorroyiatissa', 'value': 2}]},
#       {'name': 'Pitsilia Mountains',
#        'children': [{'name': 'Tsiakkas', 'value': 1}]}]},
#     {'name': 'Georgia',
#      'children': [{'name': 'Georgia',
#        'children': [{'name': 'Bagrationi 1882', 'value': 3},
#         {'name': 'Doqi', 'value': 2},
#         {'name': 'Gotsa Family Wines', 'value': 1},
#         {'name': "Iago's Wine", 'value': 1},
#         {'name': 'Teliani Valley', 'value': 2}]},
#       {'name': 'Kakheti',
#        'children': [{'name': 'Alaverdi Monastery Cellar', 'value': 1},
#         {'name': 'Antadze', 'value': 2},
#         {'name': 'Danieli', 'value': 1},
#         {'name': 'Dergi', 'value': 1},
#         {'name': 'Jakeli Wines', 'value': 1},
#         {'name': 'Kindzmarauli Marani', 'value': 2},
#         {'name': 'Marani', 'value': 6},
#         {'name': 'Our Wine', 'value': 5},
#         {'name': "Pheasant's Tears", 'value': 1},
#         {'name': 'Schuchmann Wines', 'value': 4},
#         {'name': 'Shumi Winery', 'value': 3},
#         {'name': 'Tbilvino', 'value': 6},
#         {'name': 'Telavi', 'value': 12},
#         {'name': 'Teliani Valley', 'value': 3},
#         {'name': 'Vita Vinea', 'value': 2},
#         {'name': 'Wine Man', 'value': 3}]}]},
#     {'name': 'India',
#      'children': [{'name': 'Nashik',
#        'children': [{'name': 'Sula', 'value': 4}]}]},
#     {'name': 'Israel',
#      'children': [{'name': 'Dan',
#        'children': [{'name': 'Barkan', 'value': 2}]},
#       {'name': 'Ella Valley',
#        'children': [{'name': 'Recanati', 'value': 1},
#         {'name': 'Yaffo', 'value': 3}]},
#       {'name': 'Galil',
#        'children': [{'name': 'Barkan', 'value': 7},
#         {'name': 'Jezreel', 'value': 2},
#         {'name': "Segal's", 'value': 4}]},
#       {'name': 'Galilee',
#        'children': [{'name': '1848 Winery', 'value': 3},
#         {'name': 'Alexander', 'value': 4},
#         {'name': 'Barkan', 'value': 3},
#         {'name': 'Bazelet HaGolan', 'value': 2},
#         {'name': 'Binyamina', 'value': 11},
#         {'name': 'Carmel', 'value': 18},
#         {'name': 'Dalton', 'value': 22},
#         {'name': 'Domaine Netofa', 'value': 6},
#         {'name': 'Flam', 'value': 8},
#         {'name': 'Galil Mountain', 'value': 7},
#         {'name': 'Gamla', 'value': 1},
#         {'name': 'Golan Heights Winery', 'value': 45},
#         {'name': 'Jacques Capsouto', 'value': 4},
#         {'name': 'Margalit', 'value': 1},
#         {'name': 'Odem Mountain', 'value': 3},
#         {'name': 'Or Haganuz', 'value': 9},
#         {'name': 'Pelter', 'value': 6},
#         {'name': 'Recanati', 'value': 45},
#         {'name': "Segal's", 'value': 7},
#         {'name': 'Tabor', 'value': 17},
#         {'name': 'Tulip Winery', 'value': 7},
#         {'name': 'Zion Fine Wines', 'value': 1}]},
#       {'name': 'Golan Heights',
#        'children': [{'name': 'Bazelet HaGolan', 'value': 1}]},
#       {'name': 'Haut-Judeé',
#        'children': [{'name': 'Domaine du Castel', 'value': 4}]},
#       {'name': 'Israel',
#        'children': [{'name': 'Alexander', 'value': 1},
#         {'name': 'Barkan', 'value': 1},
#         {'name': 'Carmel', 'value': 1},
#         {'name': 'Dalton', 'value': 1},
#         {'name': 'Hacormim', 'value': 4},
#         {'name': 'Jezreel', 'value': 3},
#         {'name': 'Recanati', 'value': 1}]},
#       {'name': 'Jerusalem Hills',
#        'children': [{'name': 'Pelter', 'value': 1},
#         {'name': 'Psagot', 'value': 3}]},
#       {'name': 'Judean Hills',
#        'children': [{'name': '1848 Winery', 'value': 3},
#         {'name': 'Barkan', 'value': 4},
#         {'name': 'Binyamina', 'value': 3},
#         {'name': 'Carmel', 'value': 1},
#         {'name': 'Clos de Gat', 'value': 4},
#         {'name': 'Domaine du Castel', 'value': 10},
#         {'name': 'Flam', 'value': 5},
#         {'name': 'Hevron Heights Winery', 'value': 2},
#         {'name': 'Jerusalem Wineries', 'value': 5},
#         {'name': 'Jezreel', 'value': 1},
#         {'name': 'Katlav', 'value': 3},
#         {'name': 'Montefiore', 'value': 4},
#         {'name': 'Psagot', 'value': 7},
#         {'name': 'Recanati', 'value': 2},
#         {'name': 'Shiloh Winery', 'value': 20},
#         {'name': 'Titora', 'value': 2},
#         {'name': 'Tulip Winery', 'value': 2},
#         {'name': 'Tzuba', 'value': 4},
#         {'name': 'Vitkin', 'value': 1},
#         {'name': 'Yaffo', 'value': 1},
#         {'name': 'Yatir', 'value': 8}]},
#       {'name': 'Negev', 'children': [{'name': 'Barkan', 'value': 3}]},
#       {'name': 'Negev Hills',
#        'children': [{'name': 'Kadesh Barnea', 'value': 3},
#         {'name': 'Yatir', 'value': 2}]},
#       {'name': 'Samson',
#        'children': [{'name': 'Barkan', 'value': 1},
#         {'name': 'Binyamina', 'value': 5},
#         {'name': 'Dalton', 'value': 1},
#         {'name': 'Jezreel', 'value': 2},
#         {'name': 'Mony', 'value': 2},
#         {'name': 'Teperberg', 'value': 1}]},
#       {'name': 'Shomron',
#        'children': [{'name': 'Carmel', 'value': 5},
#         {'name': 'Jerusalem Wineries', 'value': 1},
#         {'name': 'Madmon', 'value': 1},
#         {'name': 'Recanati', 'value': 5},
#         {'name': 'Teperberg', 'value': 1}]},
#       {'name': 'Upper Galilee',
#        'children': [{'name': 'Binyamina', 'value': 3},
#         {'name': 'Carmel', 'value': 5},
#         {'name': 'Galil Mountain', 'value': 13},
#         {'name': 'Makura Estate', 'value': 1},
#         {'name': 'Or Haganuz', 'value': 1},
#         {'name': 'Tulip Winery', 'value': 1}]}]},
#     {'name': 'Lebanon',
#      'children': [{'name': 'Bekaa Valley',
#        'children': [{'name': 'Château Ksara', 'value': 1},
#         {'name': 'Château Musar', 'value': 13},
#         {'name': 'Heritage', 'value': 1},
#         {'name': 'Massaya', 'value': 2}]},
#       {'name': 'Lebanon',
#        'children': [{'name': 'Château Ksara', 'value': 1},
#         {'name': 'Ixsir', 'value': 12}]}]},
#     {'name': 'Turkey',
#      'children': [{'name': 'Aegean',
#        'children': [{'name': 'Kavaklidere', 'value': 4},
#         {'name': 'Pasaeli', 'value': 5},
#         {'name': 'Paşaeli', 'value': 2},
#         {'name': 'Selendi', 'value': 1},
#         {'name': 'Sevilen', 'value': 6},
#         {'name': 'Urla', 'value': 3}]},
#       {'name': 'Ankara',
#        'children': [{'name': 'Kavaklidere', 'value': 2},
#         {'name': 'Vinkara', 'value': 11}]},
#       {'name': 'Cappadocia',
#        'children': [{'name': 'Kavaklidere', 'value': 1},
#         {'name': 'Turasan', 'value': 5}]},
#       {'name': 'Elazığ', 'children': [{'name': 'Kayra', 'value': 4}]},
#       {'name': 'Elazığ-Diyarbakir',
#        'children': [{'name': 'Kayra', 'value': 1}]},
#       {'name': 'Thrace',
#        'children': [{'name': 'Chamlija', 'value': 1},
#         {'name': 'Suvla', 'value': 8}]},
#       {'name': 'Turkey',
#        'children': [{'name': 'Diren', 'value': 2},
#         {'name': 'Kavaklidere', 'value': 1},
#         {'name': 'Kavur', 'value': 1},
#         {'name': 'Yazgan', 'value': 4}]},
#       {'name': 'Urla-Thrace', 'children': [{'name': 'Kayra', 'value': 1}]}]}]},
#   {'name': 'Europe',
#    'children': [{'name': 'Austria',
#      'children': [{'name': 'Austria',
#        'children': [{'name': 'Arndorfer', 'value': 1},
#         {'name': 'Biokult', 'value': 2},
#         {'name': 'Bründlmayer', 'value': 1},
#         {'name': 'Dürnberg', 'value': 1},
#         {'name': 'Gernot and Heike Heinrich', 'value': 1},
#         {'name': 'H. & M. Hofer', 'value': 1},
#         {'name': 'Höpler', 'value': 1},
#         {'name': 'Kracher', 'value': 1},
#         {'name': 'Lenz Moser', 'value': 1},
#         {'name': 'Pittnauer', 'value': 1},
#         {'name': 'Repolusk', 'value': 6}]},
#       {'name': 'Burgenland',
#        'children': [{'name': 'Artisan Wines DI Franz Scheider', 'value': 5},
#         {'name': 'Ernst Triebaumer', 'value': 1},
#         {'name': 'Esterházy', 'value': 19},
#         {'name': 'Feiler-Artinger', 'value': 7},
#         {'name': 'Gerhard Pittnauer', 'value': 4},
#         {'name': 'Gernot and Heike Heinrich', 'value': 6},
#         {'name': 'Gesellmann', 'value': 2},
#         {'name': 'Golser Wein', 'value': 4},
#         {'name': 'Gsellmann & Hans', 'value': 2},
#         {'name': 'Gunter Triebaumer', 'value': 35},
#         {'name': 'Hafner', 'value': 18},
#         {'name': 'Hafner Kosher', 'value': 3},
#         {'name': 'Hager Matthias', 'value': 1},
#         {'name': 'Hannes Reeh', 'value': 9},
#         {'name': 'Hans Igler', 'value': 1},
#         {'name': 'Hans Moser', 'value': 4},
#         {'name': 'Heidi Schröck', 'value': 3},
#         {'name': 'Heinrich', 'value': 4},
#         {'name': 'Heribert Bayer', 'value': 3},
#         {'name': 'Hillinger', 'value': 16},
#         {'name': 'Höpler', 'value': 12},
#         {'name': 'Iby', 'value': 6},
#         {'name': 'Jalits', 'value': 1},
#         {'name': 'Johann Heinrich', 'value': 9},
#         {'name': 'Josef Pöckl', 'value': 1},
#         {'name': 'Judith Beck', 'value': 4},
#         {'name': 'Juris', 'value': 8},
#         {'name': 'Kirnbauer', 'value': 3},
#         {'name': 'Kollwentz', 'value': 6},
#         {'name': 'Kracher', 'value': 23},
#         {'name': 'Lenz Moser', 'value': 1},
#         {'name': 'Markus Altenburger', 'value': 4},
#         {'name': 'Meinklang', 'value': 8},
#         {'name': 'Muenzenrieder', 'value': 1},
#         {'name': 'Münzenrieder', 'value': 6},
#         {'name': 'Nittnaus Anita und Hans', 'value': 13},
#         {'name': 'Nittnaus Hans und Christine', 'value': 29},
#         {'name': 'Paul Achs', 'value': 1},
#         {'name': 'Pfneisl United Vineyards', 'value': 1},
#         {'name': 'Pittnauer', 'value': 9},
#         {'name': 'Preisinger', 'value': 2},
#         {'name': 'Prieler', 'value': 13},
#         {'name': 'Pöckl', 'value': 1},
#         {'name': 'Rosenhof', 'value': 17},
#         {'name': 'Sattler', 'value': 1},
#         {'name': 'Scheiblhofer', 'value': 2},
#         {'name': 'Schloss Halbturn', 'value': 8},
#         {'name': 'Sepp Moser', 'value': 1},
#         {'name': 'Sommer', 'value': 5},
#         {'name': 'Steindorfer', 'value': 8},
#         {'name': 'Strehn', 'value': 1},
#         {'name': 'Tinhof', 'value': 13},
#         {'name': 'Umathum', 'value': 6},
#         {'name': 'Uwe Schiefer', 'value': 5},
#         {'name': 'Weninger', 'value': 9},
#         {'name': 'Wenzel', 'value': 2},
#         {'name': 'Winzerkeller Andau', 'value': 2},
#         {'name': 'Wohlmuth', 'value': 3},
#         {'name': 'Zantho', 'value': 3},
#         {'name': 'una.wine', 'value': 1}]},
#       {'name': 'Carnuntum',
#        'children': [{'name': 'Artner', 'value': 13},
#         {'name': 'Glatzer', 'value': 10},
#         {'name': 'Markowitsch', 'value': 13},
#         {'name': 'Muhr-Van der Niepoort', 'value': 5},
#         {'name': 'Nadler', 'value': 5},
#         {'name': 'Netzl', 'value': 31}]},
#       {'name': 'Eisenberg',
#        'children': [{'name': 'Jalits', 'value': 5},
#         {'name': 'Krutzler', 'value': 1},
#         {'name': 'Uwe Schiefer', 'value': 1},
#         {'name': 'Wachter Wiesler', 'value': 4},
#         {'name': 'Weninger', 'value': 1}]},
#       {'name': 'Kamptal',
#        'children': [{'name': 'Allram', 'value': 20},
#         {'name': 'Arndorfer', 'value': 2},
#         {'name': 'Brandl', 'value': 8},
#         {'name': 'Bründlmayer', 'value': 59},
#         {'name': 'Eichinger', 'value': 30},
#         {'name': 'Hiedler', 'value': 9},
#         {'name': 'Hirsch', 'value': 28},
#         {'name': 'Jurtschitsch', 'value': 15},
#         {'name': 'Kirchmayr', 'value': 1},
#         {'name': 'Kurt Angerer', 'value': 2},
#         {'name': 'Laurenz V.', 'value': 7},
#         {'name': 'Leindl', 'value': 3},
#         {'name': 'Loimer', 'value': 33},
#         {'name': 'Malat', 'value': 2},
#         {'name': 'Nastl', 'value': 3},
#         {'name': 'Rabl', 'value': 3},
#         {'name': 'Schloss Gobelsburg', 'value': 30},
#         {'name': 'Steininger', 'value': 23},
#         {'name': 'Summerer', 'value': 5},
#         {'name': 'Weixelbaum', 'value': 13},
#         {'name': 'Weszeli', 'value': 17},
#         {'name': 'Willi Brundlmayer', 'value': 1}]},
#       {'name': 'Kremstal',
#        'children': [{'name': 'Aigner', 'value': 4},
#         {'name': 'Berger', 'value': 3},
#         {'name': 'Buchegger', 'value': 7},
#         {'name': 'Emmerich Knoll', 'value': 1},
#         {'name': 'Felsner', 'value': 8},
#         {'name': 'Forstreiter', 'value': 9},
#         {'name': 'Geyerhof', 'value': 16},
#         {'name': 'Hermann Moser', 'value': 22},
#         {'name': 'Hiedler', 'value': 1},
#         {'name': 'Josef Schmid', 'value': 3},
#         {'name': 'Malat', 'value': 26},
#         {'name': 'Mantlerhof', 'value': 4},
#         {'name': 'Müller-Grossmann', 'value': 12},
#         {'name': 'Nigl', 'value': 16},
#         {'name': 'Nikolaihof', 'value': 1},
#         {'name': 'Proidl', 'value': 8},
#         {'name': 'Rainer Wess', 'value': 4},
#         {'name': 'Salomon-Undhof', 'value': 39},
#         {'name': 'Sepp Moser', 'value': 7},
#         {'name': 'Stadt Krems', 'value': 19},
#         {'name': 'Stift Göttweig', 'value': 20},
#         {'name': 'Thierry-Weber', 'value': 2},
#         {'name': 'Türk', 'value': 14},
#         {'name': 'Unger', 'value': 7},
#         {'name': 'Winzer Krems', 'value': 22},
#         {'name': 'Zimmermann', 'value': 3}]},
#       {'name': 'Leithaberg',
#        'children': [{'name': 'Nittnaus Anita und Hans', 'value': 1},
#         {'name': 'Prieler', 'value': 3}]},
#       {'name': 'Mittelburgenland',
#        'children': [{'name': 'Gesellmann', 'value': 1},
#         {'name': 'Hans Igler', 'value': 3},
#         {'name': 'Heinrich', 'value': 1},
#         {'name': 'Iby', 'value': 2},
#         {'name': 'Johann Heinrich', 'value': 3},
#         {'name': 'Kirnbauer', 'value': 1},
#         {'name': 'Pfneisl United Vineyards', 'value': 1},
#         {'name': 'Strehn', 'value': 1},
#         {'name': 'Weninger', 'value': 4}]},
#       {'name': 'Neusiedlersee',
#        'children': [{'name': 'Meinklang', 'value': 1},
#         {'name': 'Nittnaus Anita und Hans', 'value': 1},
#         {'name': 'Nittnaus Hans und Christine', 'value': 2},
#         {'name': 'Sepp Moser', 'value': 1}]},
#       {'name': 'Niederösterreich',
#        'children': [{'name': 'Arndorfer', 'value': 12},
#         {'name': 'Bernhard Ott', 'value': 5},
#         {'name': 'Brandl', 'value': 1},
#         {'name': 'Bründlmayer', 'value': 11},
#         {'name': 'Buchegger', 'value': 3},
#         {'name': 'Dürnberg', 'value': 34},
#         {'name': 'Ebner-Ebenauer', 'value': 14},
#         {'name': 'Emmerich Knoll', 'value': 1},
#         {'name': 'Familie Zull', 'value': 4},
#         {'name': 'Felsner', 'value': 4},
#         {'name': 'Forstreiter', 'value': 8},
#         {'name': 'Graf Hardegg', 'value': 15},
#         {'name': 'Gruber Röschitz', 'value': 5},
#         {'name': 'H. & M. Hofer', 'value': 10},
#         {'name': 'Hager Matthias', 'value': 4},
#         {'name': 'Hermann Moser', 'value': 5},
#         {'name': 'Hiedler', 'value': 4},
#         {'name': 'Hirsch', 'value': 2},
#         {'name': 'Hugl-Wimmer', 'value': 6},
#         {'name': 'Ingrid Groiss', 'value': 9},
#         {'name': 'Josef Ehmoser', 'value': 1},
#         {'name': 'Josef Schmid', 'value': 2},
#         {'name': 'Jurtschitsch', 'value': 3},
#         {'name': 'Kohl', 'value': 6},
#         {'name': 'Kurt Angerer', 'value': 6},
#         {'name': 'Laurenz V.', 'value': 8},
#         {'name': 'Loimer', 'value': 14},
#         {'name': 'Malat', 'value': 3},
#         {'name': 'Markus Huber', 'value': 10},
#         {'name': 'Martinshof', 'value': 4},
#         {'name': 'Maurer', 'value': 2},
#         {'name': 'Michlits', 'value': 2},
#         {'name': 'Müller-Grossmann', 'value': 3},
#         {'name': 'Nastl', 'value': 4},
#         {'name': 'Nigl', 'value': 8},
#         {'name': 'Norbert Bauer', 'value': 5},
#         {'name': 'Pleil', 'value': 1},
#         {'name': 'Pratsch', 'value': 25},
#         {'name': 'Proidl', 'value': 3},
#         {'name': 'R&A; Pfaffl', 'value': 17},
#         {'name': 'Salomon-Undhof', 'value': 12},
#         {'name': 'Schloss Gobelsburg', 'value': 13},
#         {'name': 'Schlumberger Wein- und Sektkellerei', 'value': 2},
#         {'name': 'Schwarzböck', 'value': 5},
#         {'name': 'Setzer', 'value': 3},
#         {'name': 'Sohm & Kracher', 'value': 1},
#         {'name': 'Stadlmann', 'value': 6},
#         {'name': 'Steininger', 'value': 4},
#         {'name': 'Stift Göttweig', 'value': 3},
#         {'name': 'Tegernseerhof', 'value': 1},
#         {'name': 'The Dot', 'value': 10},
#         {'name': 'Türk', 'value': 6},
#         {'name': 'Unger', 'value': 5},
#         {'name': 'Weingut Frank', 'value': 2},
#         {'name': 'Weinrieder', 'value': 6},
#         {'name': 'Weixelbaum', 'value': 4},
#         {'name': 'Winzer Krems', 'value': 36},
#         {'name': 'Zull', 'value': 22}]},
#       {'name': 'Steiermark',
#        'children': [{'name': 'Skoff', 'value': 2},
#         {'name': 'Strauss', 'value': 11}]},
#       {'name': 'Südburgenland',
#        'children': [{'name': 'Jalits', 'value': 1},
#         {'name': 'Krutzler', 'value': 1}]},
#       {'name': 'Südoststeiermark',
#        'children': [{'name': 'Neumeister', 'value': 17},
#         {'name': 'Winkler-Hermaden', 'value': 8}]},
#       {'name': 'Südsteiermark',
#        'children': [{'name': 'Erwin Sabathi', 'value': 6},
#         {'name': 'Gross', 'value': 2},
#         {'name': 'Lackner Tinnacher', 'value': 3},
#         {'name': 'Manfred Tement', 'value': 1},
#         {'name': 'Neumeister', 'value': 2},
#         {'name': 'Polz', 'value': 2},
#         {'name': 'Sattlerhof', 'value': 15},
#         {'name': 'Skoff', 'value': 5},
#         {'name': 'Strauss', 'value': 11},
#         {'name': 'Tement', 'value': 13},
#         {'name': 'Wohlmuth', 'value': 8}]},
#       {'name': 'Thermenregion',
#        'children': [{'name': 'Alphart', 'value': 1},
#         {'name': 'Fischer', 'value': 9},
#         {'name': 'Gebeshuber', 'value': 16},
#         {'name': 'Heinrich Hartl', 'value': 3},
#         {'name': 'Johanneshof Reinisch', 'value': 26},
#         {'name': 'Kirchmayr', 'value': 1},
#         {'name': 'Loimer', 'value': 3},
#         {'name': 'Stadlmann', 'value': 11},
#         {'name': 'Stift Klosterneuburg', 'value': 7}]},
#       {'name': 'Traisental',
#        'children': [{'name': 'Markus Huber', 'value': 42}]},
#       {'name': 'Vienna',
#        'children': [{'name': 'Hajszan Neumann', 'value': 5},
#         {'name': 'Mayer am Pfarrplatz', 'value': 4},
#         {'name': 'Schwarzböck', 'value': 1},
#         {'name': 'Stift Klosterneuburg', 'value': 4},
#         {'name': 'Weingut Christ', 'value': 5},
#         {'name': 'Wieninger', 'value': 28},
#         {'name': 'Zahel', 'value': 1}]},
#       {'name': 'Wachau',
#        'children': [{'name': 'Alzinger', 'value': 12},
#         {'name': 'Domäne Wachau', 'value': 59},
#         {'name': 'Eder', 'value': 13},
#         {'name': 'Emmerich Knoll', 'value': 34},
#         {'name': 'F X Pichler', 'value': 22},
#         {'name': 'Fischer', 'value': 9},
#         {'name': 'Franz Hirtzberger', 'value': 21},
#         {'name': 'Freie Weingärtner Wachau', 'value': 1},
#         {'name': 'Garber & Goltz', 'value': 2},
#         {'name': 'Gritsch Mauritiushof', 'value': 7},
#         {'name': 'Hutter', 'value': 2},
#         {'name': 'Högl', 'value': 3},
#         {'name': 'Johann Donabaum', 'value': 7},
#         {'name': 'Josef Jamek', 'value': 15},
#         {'name': 'Jäger', 'value': 19},
#         {'name': 'Lagler', 'value': 4},
#         {'name': 'Machherndl', 'value': 7},
#         {'name': 'Malat', 'value': 3},
#         {'name': 'Nikolaihof', 'value': 8},
#         {'name': 'Pichler-Krutzler', 'value': 10},
#         {'name': 'Prager', 'value': 1},
#         {'name': 'Rainer Wess', 'value': 4},
#         {'name': 'Rudi Pichler', 'value': 8},
#         {'name': 'Schmelz', 'value': 3},
#         {'name': 'Tegernseerhof', 'value': 31}]},
#       {'name': 'Wagram',
#        'children': [{'name': 'Anton Bauer', 'value': 21},
#         {'name': 'Bernhard Ott', 'value': 8},
#         {'name': 'Direder', 'value': 1},
#         {'name': 'Diwald', 'value': 4},
#         {'name': 'Ecker', 'value': 2},
#         {'name': 'Eschenhof Holzer', 'value': 1},
#         {'name': 'Fritsch', 'value': 3},
#         {'name': 'Josef Bauer', 'value': 2},
#         {'name': 'Josef Ehmoser', 'value': 3},
#         {'name': 'Leth', 'value': 9},
#         {'name': 'Weingut Groiss', 'value': 2}]},
#       {'name': 'Wagram-Donauland',
#        'children': [{'name': 'Anton Bauer', 'value': 8},
#         {'name': 'Bernhard Ott', 'value': 4},
#         {'name': 'Fritsch', 'value': 3},
#         {'name': 'Josef Ehmoser', 'value': 9},
#         {'name': 'Leth', 'value': 8},
#         {'name': 'Soellner', 'value': 1}]},
#       {'name': 'Weinland Österreich',
#        'children': [{'name': 'Dürnberg', 'value': 2},
#         {'name': 'Fuchs und Hase', 'value': 2},
#         {'name': 'Huber', 'value': 2},
#         {'name': 'Höpler', 'value': 2},
#         {'name': 'Juris', 'value': 1},
#         {'name': 'Markus Altenburger', 'value': 2},
#         {'name': 'Markus Huber', 'value': 2},
#         {'name': 'Martinshof', 'value': 1},
#         {'name': 'Weszeli', 'value': 1}]},
#       {'name': 'Weinviertel',
#        'children': [{'name': 'Dürnberg', 'value': 10},
#         {'name': 'Ebner-Ebenauer', 'value': 9},
#         {'name': 'Gruber Röschitz', 'value': 6},
#         {'name': 'H. & M. Hofer', 'value': 3},
#         {'name': 'Ingrid Groiss', 'value': 5},
#         {'name': 'Kirchmayr', 'value': 1},
#         {'name': 'Kohl', 'value': 3},
#         {'name': 'Pratsch', 'value': 2},
#         {'name': 'R&A; Pfaffl', 'value': 16},
#         {'name': 'Schwarzböck', 'value': 4},
#         {'name': 'Setzer', 'value': 7},
#         {'name': 'Zull', 'value': 2}]},
#       {'name': 'Wiener Gemischter Satz',
#        'children': [{'name': 'Weingut Christ', 'value': 1},
#         {'name': 'Weingut Mayer am Pfarrplatz', 'value': 3},
#         {'name': 'Wieninger', 'value': 6}]},
#       {'name': 'Österreichischer Perlwein',
#        'children': [{'name': 'Gebeshuber', 'value': 1},
#         {'name': 'Hafner Kosher', 'value': 1},
#         {'name': 'Hillinger', 'value': 1},
#         {'name': 'Muenzenrieder', 'value': 1}]},
#       {'name': 'Österreichischer Sekt',
#        'children': [{'name': 'Arndorfer', 'value': 1},
#         {'name': 'Biokult', 'value': 1},
#         {'name': 'Bründlmayer', 'value': 5},
#         {'name': 'Ebner-Ebenauer', 'value': 1},
#         {'name': 'Erich & Walter Polz', 'value': 2},
#         {'name': 'Gebeshuber', 'value': 1},
#         {'name': 'Graf Hardegg', 'value': 3},
#         {'name': 'Gunter Triebaumer', 'value': 1},
#         {'name': 'Malat', 'value': 2},
#         {'name': 'Markus Huber', 'value': 1},
#         {'name': 'Nigl', 'value': 1},
#         {'name': 'Pratsch', 'value': 1},
#         {'name': 'Salomon-Undhof', 'value': 1},
#         {'name': 'Schloss Gobelsburg', 'value': 1},
#         {'name': 'Schlumberger Wein- und Sektkellerei', 'value': 8},
#         {'name': 'Steininger', 'value': 15},
#         {'name': 'Szigeti', 'value': 11},
#         {'name': 'Tinhof', 'value': 1},
#         {'name': 'Winzer Krems', 'value': 2}]}]},
#     {'name': 'Bosnia and Herzegovina',
#      'children': [{'name': 'Mostar',
#        'children': [{'name': 'Winery Čitluk', 'value': 1}]}]},
#     {'name': 'Bulgaria',
#      'children': [{'name': 'Black Sea Coastal',
#        'children': [{'name': 'Targovishte', 'value': 3}]},
#       {'name': 'Bulgaria',
#        'children': [{'name': 'Villa Melnik', 'value': 1},
#         {'name': 'Vini', 'value': 1}]},
#       {'name': 'Danube River Plains',
#        'children': [{'name': 'Chateau Burgozone', 'value': 3},
#         {'name': 'Domaine Boyar', 'value': 1},
#         {'name': 'Vini', 'value': 1}]},
#       {'name': 'Thracian Valley',
#        'children': [{'name': 'Bessa', 'value': 5},
#         {'name': 'Bratanov', 'value': 2},
#         {'name': 'Bulgariana', 'value': 4},
#         {'name': 'Castra Rubra', 'value': 10},
#         {'name': 'Domaine Boyar', 'value': 8},
#         {'name': 'Edoardo Miroglio', 'value': 4},
#         {'name': 'Ivo Varbanov', 'value': 2},
#         {'name': 'Katarzyna', 'value': 4},
#         {'name': 'Logodaj', 'value': 1},
#         {'name': 'Manastira', 'value': 6},
#         {'name': 'Midalidare', 'value': 2},
#         {'name': 'Minkov Brothers', 'value': 5},
#         {'name': 'Pulden', 'value': 1},
#         {'name': 'Rumelia Wine Cellar', 'value': 1},
#         {'name': 'Villa Yambol', 'value': 1},
#         {'name': 'Villa Yustina', 'value': 1},
#         {'name': 'Vinex Slavyantsi', 'value': 3},
#         {'name': 'Vini', 'value': 23}]}]},
#     {'name': 'Croatia',
#      'children': [{'name': 'Croatia',
#        'children': [{'name': 'Bibich', 'value': 1}]},
#       {'name': 'Dalmatian Coast', 'children': [{'name': 'Vuina', 'value': 1}]},
#       {'name': 'Hvar',
#        'children': [{'name': 'Carić', 'value': 1},
#         {'name': 'Zlatan Otok', 'value': 2}]},
#       {'name': 'Istria',
#        'children': [{'name': 'Agrolaguna', 'value': 2},
#         {'name': 'Bastianich', 'value': 2},
#         {'name': 'Coronica', 'value': 1},
#         {'name': 'Istravino', 'value': 2},
#         {'name': 'Kozlović', 'value': 1},
#         {'name': 'Matošević', 'value': 2},
#         {'name': 'Piquentum', 'value': 4},
#         {'name': 'Roxanich', 'value': 1},
#         {'name': 'Saints Hills', 'value': 2},
#         {'name': 'Trapan', 'value': 2}]},
#       {'name': 'Korčula',
#        'children': [{'name': 'Pošip Čara', 'value': 1},
#         {'name': 'Toreta', 'value': 1}]},
#       {'name': 'Krk', 'children': [{'name': 'Katunar', 'value': 1}]},
#       {'name': 'Kutjevo', 'children': [{'name': 'Enjingi', 'value': 2}]},
#       {'name': 'Middle and South Dalmatia',
#        'children': [{'name': 'Saints Hills', 'value': 1}]},
#       {'name': 'North Dalmatia',
#        'children': [{'name': 'Bibich', 'value': 6},
#         {'name': 'Piližota', 'value': 1},
#         {'name': 'Suha Punta', 'value': 2}]},
#       {'name': 'Peljesac',
#        'children': [{'name': 'Istravino', 'value': 1},
#         {'name': 'Korta Katarina', 'value': 3},
#         {'name': 'Miloš', 'value': 1},
#         {'name': 'Saints Hills', 'value': 1}]},
#       {'name': 'Podunavlje',
#        'children': [{'name': 'Iločki Podrumi', 'value': 1},
#         {'name': 'Podrumi Belje', 'value': 1}]}]},
#     {'name': 'Czech Republic',
#      'children': [{'name': 'Moravia',
#        'children': [{'name': 'Stapleton & Springer', 'value': 2},
#         {'name': 'Vino z Czech', 'value': 5}]}]},
#     {'name': 'England',
#      'children': [{'name': 'England',
#        'children': [{'name': 'Bolney Wine Estate', 'value': 10},
#         {'name': 'Bride Valley Vineyard', 'value': 3},
#         {'name': 'Camel Valley', 'value': 6},
#         {'name': 'Chapel Down', 'value': 4},
#         {'name': 'Digby Fine English', 'value': 4},
#         {'name': 'Exton Park Vineyard', 'value': 3},
#         {'name': 'Gusbourne Estate', 'value': 4},
#         {'name': 'Hattingley Valley Wines', 'value': 3},
#         {'name': 'Henners', 'value': 1},
#         {'name': 'Hoffmann & Rathbone', 'value': 2},
#         {'name': 'Hush Heath Estate', 'value': 3},
#         {'name': 'Jenkyn Place Vineyard', 'value': 2},
#         {'name': 'Nyetimber', 'value': 3},
#         {'name': 'Ridgeview Estate', 'value': 13},
#         {'name': 'Stopham Estate', 'value': 1},
#         {'name': 'Sugrue Pierre Ltd.', 'value': 1},
#         {'name': 'Wiston Estate Winery', 'value': 6}]}]},
#     {'name': 'France',
#      'children': [{'name': 'Alsace',
#        'children': [{'name': 'Allimant-Laugner', 'value': 6},
#         {'name': 'André Kientzler', 'value': 11},
#         {'name': 'Antoine Moltès & Fils', 'value': 8},
#         {'name': 'Arthur Metz', 'value': 7},
#         {'name': 'Bestheim', 'value': 4},
#         {'name': 'Biecher & Schaal', 'value': 12},
#         {'name': 'Boeckel', 'value': 36},
#         {'name': 'Bott Frères', 'value': 12},
#         {'name': 'Cave de Beblenheim', 'value': 9},
#         {'name': 'Cave de Cleebourg', 'value': 18},
#         {'name': 'Cave de Hunawihr', 'value': 5},
#         {'name': 'Cave de Kientzheim-Kaysersberg', 'value': 23},
#         {'name': 'Cave de Ribeauvillé', 'value': 28},
#         {'name': 'Cave de Turckheim', 'value': 23},
#         {'name': 'Cave du Roi Dagobert', 'value': 11},
#         {'name': 'Charles Sparr', 'value': 14},
#         {'name': 'Clément Klur', 'value': 4},
#         {'name': 'Domaine Albert Mann', 'value': 7},
#         {'name': 'Domaine Allimant-Laugner', 'value': 6},
#         {'name': 'Domaine Barmès-Buecher', 'value': 45},
#         {'name': 'Domaine Bernhard & Reibel', 'value': 13},
#         {'name': 'Domaine Bott-Geyl', 'value': 28},
#         {'name': 'Domaine Charles Baur', 'value': 32},
#         {'name': 'Domaine Charles Frey', 'value': 33},
#         {'name': 'Domaine Ehrhart', 'value': 23},
#         {'name': 'Domaine Fernand Engel', 'value': 43},
#         {'name': 'Domaine François Schmitt', 'value': 15},
#         {'name': 'Domaine Fritz Schmitt', 'value': 5},
#         {'name': 'Domaine G. Metz', 'value': 11},
#         {'name': 'Domaine Gresser', 'value': 22},
#         {'name': 'Domaine Gérard Neumeyer', 'value': 6},
#         {'name': 'Domaine Jean Sipp', 'value': 10},
#         {'name': 'Domaine Loew', 'value': 4},
#         {'name': 'Domaine Marcel Deiss', 'value': 18},
#         {'name': 'Domaine Mersiol', 'value': 6},
#         {'name': 'Domaine Michel Fonne', 'value': 15},
#         {'name': 'Domaine Moltès', 'value': 9},
#         {'name': 'Domaine Ostertag', 'value': 49},
#         {'name': 'Domaine Pfister', 'value': 24},
#         {'name': 'Domaine Rieflé-Landmann', 'value': 26},
#         {'name': 'Domaine Robert Klingenfus', 'value': 4},
#         {'name': 'Domaine Roland Schmitt', 'value': 10},
#         {'name': 'Domaine Saint-Rémy', 'value': 17},
#         {'name': 'Domaine Schoffit', 'value': 45},
#         {'name': 'Domaine Seilly', 'value': 4},
#         {'name': 'Domaine Sipp-Mack', 'value': 9},
#         {'name': 'Domaine Specht', 'value': 4},
#         {'name': 'Domaine Vincent Stoeffler', 'value': 11},
#         {'name': 'Domaine Weinbach', 'value': 31},
#         {'name': 'Domaine Zinck', 'value': 35},
#         {'name': 'Domaine Zind-Humbrecht', 'value': 92},
#         {'name': 'Domaine de la Tour Blanche', 'value': 5},
#         {'name': 'Domaines Schlumberger', 'value': 45},
#         {'name': 'Dopff & Irion', 'value': 46},
#         {'name': 'Dopff Au Moulin', 'value': 14},
#         {'name': 'Emile Beyer', 'value': 19},
#         {'name': 'François Baur', 'value': 9},
#         {'name': 'Frédéric Mallo', 'value': 9},
#         {'name': 'Gustave Lorentz', 'value': 37},
#         {'name': 'Helfrich', 'value': 4},
#         {'name': 'Henri Schoenheitz', 'value': 19},
#         {'name': 'Hubert Meyer', 'value': 10},
#         {'name': 'Hugel', 'value': 18},
#         {'name': 'Jean Biecher & Fils', 'value': 4},
#         {'name': 'Jean-Baptiste Adam', 'value': 55},
#         {'name': 'Jean-Marc Bernhard', 'value': 32},
#         {'name': 'Joseph Cattin', 'value': 37},
#         {'name': 'Joseph Fritsch', 'value': 11},
#         {'name': 'Josmeyer', 'value': 14},
#         {'name': 'Julien Schaal', 'value': 4},
#         {'name': 'Klipfel', 'value': 10},
#         {'name': 'Kuentz-Bas', 'value': 69},
#         {'name': 'La Cave des Vignerons de Pfaffenheim', 'value': 18},
#         {'name': 'Leon Beyer', 'value': 10},
#         {'name': 'Louis Sipp', 'value': 7},
#         {'name': 'Lucien Albrecht', 'value': 27},
#         {'name': 'Marc Kreydenweiss', 'value': 9},
#         {'name': 'Martin Schaetzel', 'value': 11},
#         {'name': 'Maurice Schoech & Fils', 'value': 8},
#         {'name': 'Paul Blanck', 'value': 17},
#         {'name': 'Pierre Sparr', 'value': 35},
#         {'name': 'Pierre and Charles Sparr', 'value': 4},
#         {'name': 'René Muré', 'value': 36},
#         {'name': 'Rieflé', 'value': 15},
#         {'name': 'Robert Karcher et Fils', 'value': 10},
#         {'name': 'Robert Klingenfus', 'value': 5},
#         {'name': 'Ruhlmann', 'value': 16},
#         {'name': 'Sipp Mack', 'value': 9},
#         {'name': 'Trimbach', 'value': 11},
#         {'name': 'Vieil Armand', 'value': 15},
#         {'name': 'Vignoble des 2 Lunes', 'value': 8},
#         {'name': 'Willm', 'value': 51},
#         {'name': 'Wolfberger', 'value': 23},
#         {'name': 'Wunsch & Mann', 'value': 15},
#         {'name': 'Zusslin', 'value': 10},
#         {'name': 'Other wineries', 'value': 37}]},
#       {'name': 'Beaujolais',
#        'children': [{'name': 'Albert Bichot', 'value': 5},
#         {'name': 'Antonin Rodet', 'value': 2},
#         {'name': 'Barton & Guestier', 'value': 4},
#         {'name': 'Bouchard Aîné & Fils', 'value': 2},
#         {'name': 'Château de Bellevue', 'value': 3},
#         {'name': 'Château de Chatelard', 'value': 3},
#         {'name': 'Château de Javernand', 'value': 6},
#         {'name': 'Château de Juliénas', 'value': 2},
#         {'name': 'Château de Lavernette', 'value': 9},
#         {'name': 'Château de Pizay', 'value': 17},
#         {'name': 'Château de la Terrière', 'value': 5},
#         {'name': 'Château des Jacques', 'value': 6},
#         {'name': 'Château des Loges', 'value': 2},
#         {'name': 'Château du Châtelard', 'value': 8},
#         {'name': 'Château du Moulin-à-Vent', 'value': 5},
#         {'name': 'Collin-Bourisset', 'value': 3},
#         {'name': "Domaine Baron de l'Ecluse", 'value': 3},
#         {'name': 'Domaine Bertrand', 'value': 4},
#         {'name': 'Domaine Chaintreuil', 'value': 3},
#         {'name': 'Domaine Chasselay', 'value': 11},
#         {'name': 'Domaine Chignard', 'value': 5},
#         {'name': 'Domaine Cordier Père et Fils', 'value': 2},
#         {'name': 'Domaine Dubost', 'value': 7},
#         {'name': 'Domaine Dumas', 'value': 2},
#         {'name': 'Domaine Dupré', 'value': 16},
#         {'name': 'Domaine Gerard Charvet', 'value': 2},
#         {'name': 'Domaine Labruyère', 'value': 5},
#         {'name': 'Domaine Pral', 'value': 5},
#         {'name': 'Domaine de Bel Air', 'value': 7},
#         {'name': 'Domaine de Colonat', 'value': 4},
#         {'name': 'Domaine de Grand Garant', 'value': 2},
#         {'name': 'Domaine de Gry-Sablon', 'value': 4},
#         {'name': 'Domaine de Leyre-Loup', 'value': 6},
#         {'name': 'Domaine de la Bonne Tonne', 'value': 5},
#         {'name': 'Domaine de la Madone', 'value': 7},
#         {'name': 'Domaine de la Prébende', 'value': 3},
#         {'name': 'Domaine des Chers', 'value': 2},
#         {'name': 'Domaine des Marrans', 'value': 6},
#         {'name': 'Domaine des Terres Dorées', 'value': 3},
# ...
#        'children': [{'name': 'Chono', 'value': 3},
#         {'name': 'Cucao', 'value': 1},
#         {'name': 'Elki', 'value': 1},
#         {'name': 'Elqui Wines', 'value': 3},
#         {'name': 'Falernia', 'value': 16},
#         {'name': 'Lapostolle', 'value': 1},
#         {'name': 'San Pedro', 'value': 15}]},
#       {'name': 'Itata Valley',
#        'children': [{'name': 'Chilcas', 'value': 2},
#         {'name': 'Clos des Fous', 'value': 1},
#         {'name': 'De Martino', 'value': 3},
#         {'name': 'Garage Wine Co.', 'value': 1},
#         {'name': 'Garcia Schwaderer', 'value': 1},
#         {'name': 'Junta', 'value': 1},
#         {'name': 'Männle', 'value': 1},
#         {'name': 'Viña el Aromo', 'value': 1}]},
#       {'name': 'Leyda Valley',
#        'children': [{'name': 'Alto Los Romeros', 'value': 3},
#         {'name': 'Anakena', 'value': 12},
#         {'name': 'Aresti', 'value': 1},
#         {'name': 'Autoritas', 'value': 1},
#         {'name': 'Bodega Volcanes de Chile', 'value': 2},
#         {'name': 'Caliterra', 'value': 6},
#         {'name': 'Cameron Hughes', 'value': 1},
#         {'name': 'Carmen', 'value': 3},
#         {'name': 'Casas del Bosque', 'value': 1},
#         {'name': 'Casas del Toqui', 'value': 1},
#         {'name': 'Chono', 'value': 2},
#         {'name': 'Concha y Toro', 'value': 3},
#         {'name': 'Espiritu de Chile', 'value': 1},
#         {'name': 'Garces Silva', 'value': 9},
#         {'name': 'Kalfu', 'value': 4},
#         {'name': 'Leyda', 'value': 40},
#         {'name': 'Loica', 'value': 1},
#         {'name': 'Luis Felipe Edwards', 'value': 9},
#         {'name': 'Millaman', 'value': 2},
#         {'name': 'Misiones de Rengo', 'value': 3},
#         {'name': 'MontGras', 'value': 2},
#         {'name': 'Montemar', 'value': 1},
#         {'name': 'Montes', 'value': 8},
#         {'name': 'O. Fournier', 'value': 4},
#         {'name': 'Polkura', 'value': 1},
#         {'name': 'Rios de Chile', 'value': 1},
#         {'name': 'San Pedro', 'value': 7},
#         {'name': 'Santa Carolina', 'value': 14},
#         {'name': 'Santa Ema', 'value': 15},
#         {'name': 'Santa Luz', 'value': 2},
#         {'name': 'Santa Rita', 'value': 9},
#         {'name': 'Siegel', 'value': 4},
#         {'name': 'Tarapaca', 'value': 1},
#         {'name': 'Terra Andina', 'value': 1},
#         {'name': 'Undurraga', 'value': 20},
#         {'name': 'Valdivieso', 'value': 2},
#         {'name': 'Ventisquero', 'value': 5},
#         {'name': 'Viu Manent', 'value': 1},
#         {'name': 'Viña Bisquertt', 'value': 1},
#         {'name': 'Viña Casas Patronales', 'value': 2},
#         {'name': 'Viña Litoral', 'value': 2},
#         {'name': 'Viña Tarapacá', 'value': 2},
#         {'name': 'Viña Ventolera', 'value': 1}]},
#       {'name': 'Leyda Valley-Maipo Valley',
#        'children': [{'name': 'Haras de Pirque', 'value': 1},
#         {'name': 'Undurraga', 'value': 1}]},
#       {'name': 'Limarí Valley',
#        'children': [{'name': 'Chono', 'value': 1},
#         {'name': 'Concha y Toro', 'value': 15},
#         {'name': 'De Martino', 'value': 3},
#         {'name': 'La Playa', 'value': 9},
#         {'name': 'Los Molles', 'value': 6},
#         {'name': 'Maray', 'value': 7},
#         {'name': 'Maycas del Limari', 'value': 5},
#         {'name': 'Merino', 'value': 1},
#         {'name': 'Miguel Torres', 'value': 2},
#         {'name': 'Santa Alicia', 'value': 1},
#         {'name': 'Santa Carolina', 'value': 2},
#         {'name': 'Santa Rita', 'value': 1},
#         {'name': 'Sutil', 'value': 1},
#         {'name': 'Tacora', 'value': 1},
#         {'name': 'Tamaya', 'value': 14},
#         {'name': 'Undurraga', 'value': 2},
#         {'name': 'Vistamar', 'value': 1},
#         {'name': 'Viña Casas Patronales', 'value': 1},
#         {'name': 'Viña Ochotierras', 'value': 1},
#         {'name': 'Viña Tabalí', 'value': 19}]},
#       {'name': 'Lolol Valley',
#        'children': [{'name': 'Chilcas', 'value': 2},
#         {'name': 'François Lurton', 'value': 18},
#         {'name': 'J. & F. Lurton', 'value': 2}]},
#       {'name': 'Loncomilla Valley',
#        'children': [{'name': 'Carta Vieja', 'value': 2},
#         {'name': 'Cremaschi Furlotti', 'value': 7},
#         {'name': 'G7', 'value': 4},
#         {'name': 'Gillmore', 'value': 2},
#         {'name': 'Morandé', 'value': 4}]},
#       {'name': 'Lontué Valley',
#        'children': [{'name': 'Alta Cima', 'value': 2},
#         {'name': 'Fernando Torres Torrent', 'value': 1},
#         {'name': 'Korta', 'value': 5},
#         {'name': 'Odfjell', 'value': 4},
#         {'name': 'San Pedro', 'value': 4},
#         {'name': 'Santa Rita', 'value': 1},
#         {'name': 'Valdivieso', 'value': 2},
#         {'name': 'Viña La Fortuna', 'value': 4}]},
#       {'name': 'Maipo Valley',
#        'children': [{'name': 'Agustinos', 'value': 5},
#         {'name': 'Antiyal', 'value': 8},
#         {'name': 'Apaltagua', 'value': 3},
#         {'name': 'Aresti', 'value': 2},
#         {'name': 'Baron Philippe de Rothschild', 'value': 2},
#         {'name': 'Bodega Volcanes de Chile', 'value': 3},
#         {'name': 'Carmen', 'value': 15},
#         {'name': 'Casa Julia', 'value': 2},
#         {'name': 'Casa Rivas', 'value': 7},
#         {'name': 'Casas del Toqui', 'value': 3},
#         {'name': 'Chono', 'value': 5},
#         {'name': 'Concha y Toro', 'value': 16},
#         {'name': 'Cono Sur', 'value': 8},
#         {'name': 'Cousiño-Macul', 'value': 20},
#         {'name': 'De Martino', 'value': 23},
#         {'name': 'Echeverria', 'value': 11},
#         {'name': 'Errazuriz', 'value': 4},
#         {'name': 'Garage Wine Co.', 'value': 5},
#         {'name': 'Haras', 'value': 5},
#         {'name': 'Haras de Pirque', 'value': 3},
#         {'name': 'Indomita', 'value': 16},
#         {'name': 'La Playa', 'value': 3},
#         {'name': 'Mancura', 'value': 6},
#         {'name': 'Matetic', 'value': 2},
#         {'name': 'MontGras', 'value': 3},
#         {'name': 'Morandé', 'value': 31},
#         {'name': 'Ochagavia', 'value': 5},
#         {'name': 'Odfjell', 'value': 19},
#         {'name': 'Pargua', 'value': 3},
#         {'name': 'Porta', 'value': 2},
#         {'name': 'Portal Del Alto', 'value': 5},
#         {'name': 'San Pedro', 'value': 4},
#         {'name': 'Santa Alicia', 'value': 78},
#         {'name': 'Santa Carolina', 'value': 7},
#         {'name': 'Santa Ema', 'value': 47},
#         {'name': 'Santa Ines', 'value': 2},
#         {'name': 'Santa Rita', 'value': 33},
#         {'name': 'Tarapaca', 'value': 6},
#         {'name': 'Teillery', 'value': 2},
#         {'name': 'TerraMater', 'value': 3},
#         {'name': 'Tres Palacios', 'value': 31},
#         {'name': 'Undurraga', 'value': 37},
#         {'name': 'Ventisquero', 'value': 17},
#         {'name': 'Vistamar', 'value': 8},
#         {'name': 'Viña Casablanca', 'value': 5},
#         {'name': 'Viña Chocalan', 'value': 11},
#         {'name': 'Viña Maipo', 'value': 2},
#         {'name': 'Viña Pérez Cruz', 'value': 8},
#         {'name': 'Viña Tarapacá', 'value': 10},
#         {'name': 'Viña el Principal', 'value': 14},
#         {'name': 'William Fèvre', 'value': 6},
#         {'name': 'Other wineries', 'value': 14}]},
#       {'name': 'Maipo Valley-Colchagua Valley',
#        'children': [{'name': 'Echeverria', 'value': 2},
#         {'name': 'Undurraga', 'value': 1}]},
#       {'name': 'Malleco',
#        'children': [{'name': 'Viña Aquitania', 'value': 2},
#         {'name': 'William Fèvre', 'value': 1}]},
#       {'name': 'Marchigue',
#        'children': [{'name': 'Concha y Toro', 'value': 8},
#         {'name': 'Polkura', 'value': 8},
#         {'name': 'Viña Bisquertt', 'value': 2}]},
#       {'name': 'Maule Valley',
#        'children': [{'name': 'Aguirre', 'value': 6},
#         {'name': 'Alcance', 'value': 4},
#         {'name': 'Alfasi', 'value': 1},
#         {'name': 'Altamana', 'value': 3},
#         {'name': 'Alto Los Romeros', 'value': 2},
#         {'name': 'Apaltagua', 'value': 5},
#         {'name': 'Balduzzi', 'value': 19},
#         {'name': 'Bodega Volcanes de Chile', 'value': 3},
#         {'name': 'Bodegas Manutara', 'value': 1},
#         {'name': 'Bossy Boots', 'value': 2},
#         {'name': 'Botalcura', 'value': 2},
#         {'name': 'Caliboro Estate', 'value': 4},
#         {'name': 'Calina', 'value': 12},
#         {'name': 'Carma', 'value': 2},
#         {'name': 'Carta Vieja', 'value': 1},
#         {'name': 'Casa Donoso', 'value': 8},
#         {'name': 'Chilcas', 'value': 34},
#         {'name': 'Chilensis', 'value': 34},
#         {'name': 'Coleccion Privada', 'value': 2},
#         {'name': 'Concha y Toro', 'value': 2},
#         {'name': 'Cousiño-Macul', 'value': 1},
#         {'name': 'Creación', 'value': 3},
#         {'name': 'Cremaschi Furlotti', 'value': 1},
#         {'name': 'Cuevas del Sur', 'value': 1},
#         {'name': 'De Martino', 'value': 2},
#         {'name': 'Finca Patagonia', 'value': 16},
#         {'name': 'Francisco Gillmore', 'value': 4},
#         {'name': 'Garage Wine Co.', 'value': 6},
#         {'name': 'Gillmore', 'value': 1},
#         {'name': 'Grÿphus', 'value': 2},
#         {'name': 'Hugo Casanova', 'value': 1},
#         {'name': 'Imperial', 'value': 1},
#         {'name': 'J. Bouchon', 'value': 5},
#         {'name': 'Kunza', 'value': 4},
#         {'name': 'Las Casas de Vacquería', 'value': 1},
#         {'name': 'Leyendas de Familia', 'value': 5},
#         {'name': 'Luis Felipe Edwards', 'value': 1},
#         {'name': 'Luma Chequén', 'value': 3},
#         {'name': 'Mancura', 'value': 3},
#         {'name': 'Meli', 'value': 1},
#         {'name': 'Millaman', 'value': 1},
#         {'name': 'Morandé', 'value': 7},
#         {'name': 'O. Fournier', 'value': 11},
#         {'name': 'Odfjell', 'value': 7},
#         {'name': 'Oveja Negra', 'value': 25},
#         {'name': 'P.K.N.T.', 'value': 2},
#         {'name': 'Palo Alto', 'value': 12},
#         {'name': 'Portal Del Alto', 'value': 3},
#         {'name': 'San Nicolas', 'value': 1},
#         {'name': 'San Pedro', 'value': 21},
#         {'name': 'Santa Alba', 'value': 5},
#         {'name': 'Santa Carolina', 'value': 3},
#         {'name': 'Santa Ema', 'value': 2},
#         {'name': 'Santa Isle', 'value': 1},
#         {'name': 'Santa Luz', 'value': 1},
#         {'name': 'Sierra Batuco', 'value': 7},
#         {'name': 'Simone', 'value': 6},
#         {'name': 'Sundance', 'value': 3},
#         {'name': 'TerraNoble', 'value': 10},
#         {'name': 'Torres', 'value': 1},
#         {'name': 'Tricky Rabbit', 'value': 5},
#         {'name': 'Undurraga', 'value': 4},
#         {'name': 'V Norte', 'value': 1},
#         {'name': 'Valdivieso', 'value': 4},
#         {'name': 'Valle Frio', 'value': 2},
#         {'name': 'Vistamar', 'value': 1},
#         {'name': 'Viña Casas Patronales', 'value': 23},
#         {'name': 'Viña Maipo', 'value': 4},
#         {'name': 'Viña Marty', 'value': 3},
#         {'name': 'Viña Requingua', 'value': 15},
#         {'name': 'Viña San Vicente', 'value': 6},
#         {'name': 'Viña Tinajas', 'value': 1},
#         {'name': 'Viña el Aromo', 'value': 9}]},
#       {'name': 'Molina',
#        'children': [{'name': 'Echeverria', 'value': 4},
#         {'name': 'Floria', 'value': 1},
#         {'name': 'Quasar', 'value': 3}]},
#       {'name': 'Peumo',
#        'children': [{'name': 'Anakena', 'value': 2},
#         {'name': 'Casas del Toqui', 'value': 2},
#         {'name': 'Concha y Toro', 'value': 18},
#         {'name': 'Santa Carolina', 'value': 3},
#         {'name': 'Santa Ema', 'value': 7},
#         {'name': 'Undurraga', 'value': 1},
#         {'name': 'Valdivieso', 'value': 3}]},
#       {'name': 'Pirque',
#        'children': [{'name': 'Concha y Toro', 'value': 3},
#         {'name': 'Undurraga', 'value': 2},
#         {'name': 'William Fèvre', 'value': 1}]},
#       {'name': 'Puente Alto',
#        'children': [{'name': 'Concha y Toro', 'value': 10}]},
#       {'name': 'Rapel Valley',
#        'children': [{'name': 'Agustinos', 'value': 2},
#         {'name': 'Altaïr', 'value': 4},
#         {'name': 'Anakena', 'value': 2},
#         {'name': 'Aresti', 'value': 1},
#         {'name': 'Bodega Volcanes de Chile', 'value': 2},
#         {'name': 'Botalcura', 'value': 1},
#         {'name': 'Carmen', 'value': 1},
#         {'name': 'Casa Viva', 'value': 1},
#         {'name': 'Casas del Bosque', 'value': 4},
#         {'name': 'Château Los Boldos', 'value': 6},
#         {'name': 'Concha y Toro', 'value': 12},
#         {'name': 'Cono Sur', 'value': 1},
#         {'name': 'Dallas Conté', 'value': 1},
#         {'name': 'El Toqui', 'value': 1},
#         {'name': 'Emiliana', 'value': 12},
#         {'name': 'Gracia de Chile', 'value': 1},
#         {'name': 'La Palma', 'value': 2},
#         {'name': 'Lapostolle', 'value': 27},
#         {'name': 'Misiones de Rengo', 'value': 6},
#         {'name': 'Morandé', 'value': 1},
#         {'name': 'Ochagavia', 'value': 1},
#         {'name': 'PKNT', 'value': 2},
#         {'name': 'Pura 8', 'value': 3},
#         {'name': 'Quintay', 'value': 3},
#         {'name': 'Santa Carolina', 'value': 15},
#         {'name': 'Santa Ema', 'value': 2},
#         {'name': 'Santa Monica', 'value': 1},
#         {'name': 'Santa Rita', 'value': 10},
#         {'name': 'Undurraga', 'value': 8},
#         {'name': 'Viña Casablanca', 'value': 2},
#         {'name': 'Viña Casas del Bosque', 'value': 1},
#         {'name': 'Viña Maipo', 'value': 2},
#         {'name': 'Yali', 'value': 3}]},
#       {'name': 'Requinoa',
#        'children': [{'name': 'Château Los Boldos', 'value': 2}]},
#       {'name': 'Rio Claro', 'children': [{'name': 'Aresti', 'value': 5}]},
#       {'name': 'Sagrada Familia',
#        'children': [{'name': 'Discreto', 'value': 1},
#         {'name': 'Valdivieso', 'value': 1}]},
#       {'name': 'San Antonio',
#        'children': [{'name': 'Anakena', 'value': 1},
#         {'name': 'Apaltagua', 'value': 6},
#         {'name': 'Casa Marin', 'value': 6},
#         {'name': 'Cono Sur', 'value': 8},
#         {'name': 'Lapostolle', 'value': 1},
#         {'name': 'Leyda', 'value': 2},
#         {'name': 'Matetic', 'value': 28},
#         {'name': 'MontGras', 'value': 2},
#         {'name': 'Santa Carolina', 'value': 3},
#         {'name': 'Undurraga', 'value': 5},
#         {'name': 'Viña Chocalan', 'value': 3}]},
#       {'name': 'San Clemente',
#        'children': [{'name': 'Concha y Toro', 'value': 2},
#         {'name': 'TerraNoble', 'value': 1}]},
#       {'name': 'Santa Cruz',
#        'children': [{'name': 'Left Bend', 'value': 1},
#         {'name': 'Montes', 'value': 4},
#         {'name': 'Valdivieso', 'value': 1}]}]},
#     {'name': 'Peru',
#      'children': [{'name': 'Ica',
#        'children': [{'name': 'Intipalka', 'value': 9},
#         {'name': 'Tacama', 'value': 7}]}]},
#     {'name': 'Uruguay',
#      'children': [{'name': 'Atlantida',
#        'children': [{'name': 'Bracco Bosca', 'value': 2},
#         {'name': 'Viñedo de los Vientos', 'value': 3}]},
#       {'name': 'Canelones',
#        'children': [{'name': 'Antigua Bodega Stagnari', 'value': 3},
#         {'name': 'Ariano Hermanos', 'value': 3},
#         {'name': 'Artesana', 'value': 4},
#         {'name': 'Bouza', 'value': 3},
#         {'name': 'Familia Deicas', 'value': 2},
#         {'name': 'Gimenez Mendez', 'value': 6},
#         {'name': 'Marichal', 'value': 9},
#         {'name': 'Montes Toscanini', 'value': 4},
#         {'name': 'Pizzorno', 'value': 3}]},
#       {'name': 'Juanico',
#        'children': [{'name': 'Familia Deicas', 'value': 7},
#         {'name': 'Pueblo del Sol', 'value': 1}]},
#       {'name': 'Montevideo',
#        'children': [{'name': 'Bouza', 'value': 5},
#         {'name': 'Familia Traversa', 'value': 1},
#         {'name': 'Gimenez Mendez', 'value': 2}]},
#       {'name': 'Progreso', 'children': [{'name': 'Pisano', 'value': 11}]},
#       {'name': 'San Jose',
#        'children': [{'name': 'Castillo Viejo', 'value': 3}]},
#       {'name': 'Uruguay',
#        'children': [{'name': 'Alto de la Ballena', 'value': 2},
#         {'name': 'Bodegas Carrau', 'value': 3},
#         {'name': 'Bouza', 'value': 2},
#         {'name': 'Familia Deicas', 'value': 2},
#         {'name': 'Familia Traversa', 'value': 2},
#         {'name': 'Garzón', 'value': 7},
#         {'name': 'Gimenez Mendez', 'value': 1},
#         {'name': 'Narbona', 'value': 3},
#         {'name': 'Pizzorno', 'value': 1}]}]}]}]}

# %%
# def create_hierarchy(data):
#     # Creating the root of the hierarchy
#     hierarchy = {"name": "Continents", "children": []}
    
#     # Grouping by the highest level: Continent
#     for continent, continent_group in data.groupby("continent"):
#         continent_dict = {"name": continent, "children": []}
        
#         # Grouping by the next level: Country
#         for country, country_group in continent_group.groupby("country"):
#             country_dict = {"name": country, "children": []}
            
#             # Grouping by the next level: Province
#             for province, province_group in country_group.groupby("province"):
#                 province_dict = {"name": province, "children": []}
                
#                 # Processing each Winery
#                 for index, row in province_group.iterrows():
                    
#                     winery_dict = {"name": index[2], "value": int(row["count"])}
#                     province_dict["children"].append(winery_dict)
#                     print(winery_dict)
                
#                 country_dict["children"].append(province_dict)
            
#             continent_dict["children"].append(country_dict)

#         hierarchy["children"].append(continent_dict)
    
#     return hierarchy

# # Generate the hierarchical JSON structure
# hierarchy_json = create_hierarchy(df_treemap)

# %%
import json

# Convert the hierarchy dictionary to a JSON string
json_data = json.dumps(hierarchy_json, indent=4)

# Define the file path
file_path = 'winery_hierarchy.json'

# Write the JSON string to a file
with open(file_path, 'w') as file:
    file.write(json_data)

print(f"Data saved to {file_path}")
# Out:
# Data saved to winery_hierarchy.json
